# %% [markdown]
# # HEADERS
#
# ## HEADER 2
#
# ### HEADER 3
# ---
# # ITALICS
#
# *ITALICS*
#
# ---
# # BOLD
#
# **BOLD**
#
# ---
# # COMBINATION
#
# #### *HEADER 4*
#
# ***BOLD AND ITALICS***
#
# ---
# # CODE REPRESENTATION
#
# `CODE`
#
# *`CODE`*
#
# ---
# # 1. LIST
#
# ## *1. UNORDERED LIST*
#
# * A
# * B
#     * C
#     * D
# * E
#
# ## *2. ORDERED LIST*
#
# 1. A
# 2. B
#     1. C
#     1. D
# 1. E
#
# ---
# # LINKS
#
# ## *1. REFERENCE LINK*
#
# [EXAMPLE OF REFERENCE LINK][1]
#
# [1]: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
#
#
# ## *2. INLINE LINKS*
#
# [EXAMPLE OF INLINE LINK](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# ---
# # IMAGES
#
# ![PORCHE 911 CARERRA IMAGE DISPLAYED USING REFERENCE LINK][2]
#
# [2]: https://di-uploads-pod15.dealerinspire.com/porschemilwaukeenorth/uploads/2020/09/2021-Porsche-911-Turbo-S.jpg
#
# ---
# # NEW LINE
#
# ```
# THIS
# IS
# ONE
# LINE
# ```
